# %% [markdown]
# # CNN and SVM

# %% [markdown]
# GPU Configurations:-

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %% [markdown]
# # Import TensorFlow and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pathlib

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2

# %%
tf.__version__
# Out:
# '2.9.1'

# %% [markdown]
# # Explore the dataset

# %%
data_dir = pathlib.Path('../dataset_stages/train')
data_dir
# Out:
# WindowsPath('../dataset_stages/train')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 11521

# %%
mild = list(data_dir.glob('Mild_Demented/*'))
PIL.Image.open(str(mild[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x2711F83E400>

# %%
PIL.Image.open(str(mild[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=176x208 at 0x2711F470FD0>

# %%
v_mild = list(data_dir.glob('Very_Mild_Demented/*'))
PIL.Image.open(str(v_mild[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x2711F6DBE50>

# %%
PIL.Image.open(str(v_mild[42]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=176x208 at 0x2711F8E8A60>

# %% [markdown]
# # Load using keras.preprocessing

# %% [markdown]
# ### Create a dataset

# %%
batch_size = 16
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="training",
  seed=123,
  labels='inferred',
  label_mode='int',
  image_size=(img_height, img_width),
  batch_size=batch_size)

train_ds
# Out:
# Found 11521 files belonging to 4 classes.
# Using 10369 files for training.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="validation",
  seed=123,
  labels='inferred',
  label_mode='int',
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds
# Out:
# Found 11521 files belonging to 4 classes.
# Using 1152 files for validation.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']

# %% [markdown]
# # Visualize the data

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
    
plt.savefig('stages.png')

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 180, 180, 3)
# (16,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
# normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# image_batch, labels_batch = next(iter(normalized_ds))
# first_image = image_batch[0]
# # Notice the pixels values are now in `[0,1]`.
# print(np.min(first_image), np.max(first_image))

# %% [markdown]
# # Create the model

# %%
base_model = tf.keras.models.load_model('../saved_model/base_model.h5')

# %%
base_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 90, 90, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 45, 45, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 23, 23, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 64)          18496
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  global_max_pooling2d (Globa  (None, 64)               0
#  lMaxPooling2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 48,674
# Trainable params: 48,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model.trainable = False

# %%
# num_classes = 4

# model = Sequential([
#     layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
#     layers.Conv2D(16, 3, padding='same', strides=2, activation='relu'),
#     layers.MaxPooling2D(),
#     layers.Conv2D(32, 3, padding='same', strides=2, activation='relu'),
#     layers.MaxPooling2D(),
#     layers.Conv2D(64, 3, padding='same', strides=2, activation='relu'),
#     layers.MaxPooling2D(),
#     layers.GlobalMaxPooling2D(),
#     layers.Flatten(),
#     layers.Dense(128, activation='relu'),
#     layers.Dense(128, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation='linear'),
#     layers.Dense(num_classes, activation='softmax')
# ])

# %%
num_classes = 4

inputs = tf.keras.Input(shape=(img_height, img_width, 3))
preprocess = tf.keras.layers.Rescaling(1./255)(inputs)
conv1 = layers.Conv2D(16, 3, padding='same', strides=2, activation='relu')(preprocess)
maxpool1 = layers.MaxPooling2D()(conv1)
conv2 = layers.Conv2D(32, 3, padding='same', strides=2, activation='relu')(maxpool1)
maxpool2 = layers.MaxPooling2D()(conv2)
conv3 = layers.Conv2D(64, 3, padding='same', strides=2, activation='relu')(maxpool2)
maxpool3 = layers.MaxPooling2D()(conv3)
global_maxpool = layers.GlobalMaxPooling2D()(maxpool3)
flatten = layers.Flatten()(global_maxpool)
dense1 = layers.Dense(128, activation='relu')(flatten)
dense2 = layers.Dense(128, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation='linear')(dense1)

feature2 = base_model(inputs)

concat = layers.Concatenate()([dense2, feature2])

output = layers.Dense(num_classes, activation='softmax')(concat)

# %%
model = tf.keras.models.Model(inputs = [inputs], outputs = output)

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# # Model summary

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 180, 180, 3)  0           ['input_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 90, 90, 16)   448         ['rescaling_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 45, 45, 16)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 23, 23, 32)   4640        ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 11, 11, 32)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 6, 6, 64)     18496       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 3, 3, 64)    0           ['conv2d_5[0][0]']
#
#  global_max_pooling2d_1 (Global  (None, 64)          0           ['max_pooling2d_5[0][0]']
#  MaxPooling2D)
#
#  flatten_1 (Flatten)            (None, 64)           0           ['global_max_pooling2d_1[0][0]']
#
#  dense_3 (Dense)                (None, 128)          8320        ['flatten_1[0][0]']
#
#  dense_4 (Dense)                (None, 128)          16512       ['dense_3[0][0]']
#
#  sequential (Sequential)        (None, 2)            48674       ['input_1[0][0]']
#
#  concatenate (Concatenate)      (None, 130)          0           ['dense_4[0][0]',
#                                                                   'sequential[0][0]']
#
#  dense_5 (Dense)                (None, 4)            524         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 97,614
# Trainable params: 48,940
# Non-trainable params: 48,674
# __________________________________________________________________________________________________

# %% [markdown]
# # Train the model

# %%
callback1 = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=1, verbose=1)
callback2 = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=1, verbose=1)
callback3 = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, verbose=1)
callback4 = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=2, verbose=1)

# %%
epochs=10
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    shuffle=True,
    callbacks=[callback1, callback2, callback3, callback4]
    # callbacks=[callback1,]
)
# Out:
# Epoch 1/10
# 649/649 [==============================] - 13s 10ms/step - loss: 1.0664 - accuracy: 0.6124 - val_loss: 0.7093 - val_accuracy: 0.7535
# Epoch 2/10
# 649/649 [==============================] - 6s 9ms/step - loss: 0.5825 - accuracy: 0.8281 - val_loss: 0.4341 - val_accuracy: 0.9089
# Epoch 3/10
# 649/649 [==============================] - 6s 9ms/step - loss: 0.3608 - accuracy: 0.9081 - val_loss: 0.2623 - val_accuracy: 0.9427
# Epoch 4/10
# 649/649 [==============================] - 6s 9ms/step - loss: 0.2204 - accuracy: 0.9494 - val_loss: 0.1666 - val_accuracy: 0.9661
# Epoch 5/10
# 649/649 [==============================] - 6s 9ms/step - loss: 0.1494 - accuracy: 0.9678 - val_loss: 0.1358 - val_accuracy: 0.9679
# Epoch 6/10
# 649/649 [==============================] - 6s 9ms/step - loss: 0.1119 - accuracy: 0.9775 - val_loss: 0.0956 - val_accuracy: 0.9861
# Epoch 7/10
# 649/649 [==============================] - 6s 9ms/step - loss: 0.0833 - accuracy: 0.9853 - val_loss: 0.0857 - val_accuracy: 0.9792
# Epoch 8/10
# 649/649 [==============================] - 6s 9ms/step - loss: 0.0656 - accuracy: 0.9885 - val_loss: 0.0627 - val_accuracy: 0.9861
# Epoch 8: early stopping

# %%
model.save('../saved_model/_mian_model.h5')

# %% [markdown]
# ## Evaluate the model on test data

# %%
data_dir_test = pathlib.Path('../dataset_stages/test')
data_dir_test
# Out:
# WindowsPath('../dataset_stages/test')

# %%
image_count = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count)
# Out:
# 1279

# %%
mild = list(data_dir.glob('Mild_Demented/*'))
PIL.Image.open(str(mild[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x214846CBC40>

# %% [markdown]
# ### Create test dataset

# %%
batch_size = 16
img_height = 180
img_width = 180

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  seed=123,
  labels='inferred',
  label_mode='int',
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_ds
# Out:
# Found 1279 files belonging to 4 classes.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model.evaluate(test_ds)
# Out:
# 80/80 [==============================] - 1s 10ms/step - loss: 0.1055 - accuracy: 0.9679
# [0.10549039393663406, 0.9679437279701233]
