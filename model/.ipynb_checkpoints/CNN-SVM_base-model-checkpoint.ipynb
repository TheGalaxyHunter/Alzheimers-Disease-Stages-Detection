# %% [markdown]
# # CNN and SVM

# %% [markdown]
# GPU Configurations:-

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %% [markdown]
# # Import TensorFlow and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pathlib

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2

# %%
tf.__version__
# Out:
# '2.9.1'

# %% [markdown]
# # Explore the dataset

# %%
data_dir = pathlib.Path('../dataset/')
data_dir
# Out:
# WindowsPath('../dataset')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 11692

# %%
positive = list(data_dir.glob('positive/*'))
PIL.Image.open(str(positive[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=256x256 at 0x28AAA5E5F70>

# %%
PIL.Image.open(str(positive[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=256x256 at 0x28ADDF183D0>

# %%
negative = list(data_dir.glob('negative/*'))
PIL.Image.open(str(negative[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128 at 0x28ADDF18850>

# %%
PIL.Image.open(str(negative[42]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=176x208 at 0x28ADE228190>

# %% [markdown]
# # Load using keras.preprocessing

# %% [markdown]
# ### Create a dataset

# %%
batch_size = 16
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="training",
  seed=123,
  labels='inferred',
  label_mode='int',
  image_size=(img_height, img_width),
  batch_size=batch_size)

train_ds
# Out:
# Found 11692 files belonging to 2 classes.
# Using 10523 files for training.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="validation",
  seed=123,
  labels='inferred',
  label_mode='int',
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds
# Out:
# Found 11692 files belonging to 2 classes.
# Using 1169 files for validation.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['negative', 'positive']

# %% [markdown]
# # Visualize the data

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
    
plt.savefig('pos-neg.png')

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 180, 180, 3)
# (16,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
# normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# image_batch, labels_batch = next(iter(normalized_ds))
# first_image = image_batch[0]
# # Notice the pixels values are now in `[0,1]`.
# print(np.min(first_image), np.max(first_image))

# %% [markdown]
# # Create the model

# %%
num_classes = 2

model = Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, 3, padding='same', strides=2, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', strides=2, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', strides=2, activation='relu'),
    layers.MaxPooling2D(),
    layers.GlobalMaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(128, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation='linear'),
    layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# # Model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 90, 90, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 45, 45, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 23, 23, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 64)          18496
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  global_max_pooling2d (Globa  (None, 64)               0
#  lMaxPooling2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 48,674
# Trainable params: 48,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
import visualkeras
from PIL import ImageFont

visualkeras.layered_view(model, legend=True, font=font)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 import visualkeras
#       2 from PIL import ImageFont
#       4 visualkeras.layered_view(model, legend=True, font=font)
#
# ModuleNotFoundError: No module named 'visualkeras'

# %% [markdown]
# # Train the model

# %%
callback1 = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=1, verbose=1)
callback2 = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=1, verbose=1)
callback3 = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, verbose=1)
callback4 = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=2, verbose=1)

# %%
epochs=10
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    shuffle=True,
    callbacks=[callback1, callback2, callback3, callback4]
    # callbacks=[callback1,]
)
# Out:
# Epoch 1/10
# 658/658 [==============================] - 122s 64ms/step - loss: 0.7463 - accuracy: 0.6300 - val_loss: 0.5667 - val_accuracy: 0.7134
# Epoch 2/10
# 658/658 [==============================] - 10s 15ms/step - loss: 0.5116 - accuracy: 0.7562 - val_loss: 0.4129 - val_accuracy: 0.8306
# Epoch 3/10
# 658/658 [==============================] - 10s 15ms/step - loss: 0.3853 - accuracy: 0.8290 - val_loss: 0.3163 - val_accuracy: 0.8717
# Epoch 4/10
# 658/658 [==============================] - 10s 15ms/step - loss: 0.2571 - accuracy: 0.8977 - val_loss: 0.2583 - val_accuracy: 0.8999
# Epoch 5/10
# 658/658 [==============================] - 10s 15ms/step - loss: 0.1643 - accuracy: 0.9399 - val_loss: 0.2322 - val_accuracy: 0.9110
# Epoch 6/10
# 658/658 [==============================] - 9s 14ms/step - loss: 0.1109 - accuracy: 0.9631 - val_loss: 0.1295 - val_accuracy: 0.9589
# Epoch 7/10
# 658/658 [==============================] - 10s 15ms/step - loss: 0.0850 - accuracy: 0.9722 - val_loss: 0.1187 - val_accuracy: 0.9572
# Epoch 8/10
# 658/658 [==============================] - 10s 15ms/step - loss: 0.0568 - accuracy: 0.9835 - val_loss: 0.1156 - val_accuracy: 0.9538
# Epoch 8: early stopping

# %%
model.save('../saved_model/base_model.h5')
